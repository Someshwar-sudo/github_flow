# %% [markdown]
# **Github**

# %% [markdown]
# - GitHub is a proprietary developer platform that allows developers to create, store, manage, and share their code.
#
# - It uses Git to provide distributed version control and GitHub itself provides access control, bug tracking, software feature requests,
#   task management, continuous integration, and wikis for every project.

# %%
**steps to follow**

- 1.Create a repository in the github whcih are having the poroject files.

- 2.In order to pull the repo in our laptop ,we need to create a folder in laptop.**{file name='ashok_github in documents in c drive'}**

- 3.Open cmd and type cd <filder path>.**{user/ashok/c/documents/ashok_github}**

- 4.We are in inside the folder ,now we are right position to pull the repo in this folder by using commond.

    - **command-1** :- git clone <repo_url>

    - Notes:- we can get this repo_url in the codes tab 

        ############################################
          # command 1: git clone <repository url>
          ############################################

- 5.We succesfully pulled the files to folder.

- 6.Verify the files in folder ,then you can see the project file name in our **ashok_github**

- 7.Now open cmd enter cd file path including the file folder ,present we are inside the project file 

- 8.check the **branch name**

    - **command-2** : git branch -a

        ##################################
             Command-2: git branch -a   
                    or 
                    git branch
         ###################################

- 9.Then you can see the one branch name **main**

    - **star** denotes the we are in present or current branch in green colour

    - red colour code means it present in the repo or github

- 10.Now we have to create our new branch by using command .Ex:- Brnach name is **porniith-shiv**

    - **command-3** : git branch porniith-shiv

             ###################################
            # comand: git branch porniith-shiv #
            ###################################

- 11.Now it is created the new branch .

    - to verify the new branch use the command **git branch -a**

- 12.New branch created in locally ,so in order to see in repo we have to push this by command

    - **command-4** : git push origin <branch name> i.e git push origin porniith-shiv

                #################################  
                   git push origin <branch_name>
                   git push origin porniith-shiv
                ##################################

- 13.Created new branch sucesfully in Gitrepo but we are still in the main branch only now we have
     to change or shift  from main branch to **porniith-shiv**  branch by using command

     - **command-5** git checkout porniith-shiv

        #################################################
            command:  git checkout <branch_name>
                      git checkout porniith-shiv
          ##################################################

- 14.Now ,where ever we need to make the changes ,lets make it after that we need to check where these changes took by
     using command

    - **command-6** git status

    - now you can see the location where we did the changes 

                    #######################
                  # command: git status #
                  #######################

- 15.we cant see the changes in the repo file ,so modified code should add to gitrepo by using command

    - **command-7** : git add .

             ########################
              # command: git add .   #
              ########################

- 16. before commit the changes lets mentioned what we did by using command

    - **command-8** : git commit -am "msg"

            ################################################
               command :  git commit -am<msg>
                          git commit -am "workspace updated"
             ###################################################

- 17. Finally we will push the changes 
     
          ###############################################
               command: git push origin <branch name>
                        git push origin porniith-shiv
    ################################################################

- 18.Rise the PR:Pull Request 

    - manager checks and accepte and merge the file 

- 19.branch need to be deleted locally:  

         ################################################
            command: git branch -D <branch_name>
                     git branch --delete <branch_name>
        ###################################################

- 20.Note: Branch will not delete if you are on that currently
     So first checkout to main, then delete branch
       ###################################################
          git checkout main 
       #####################################################

- 21. branch need to be deleted remote 

           ###############################################
             Command: git push origin -d <branch_name>
           ################################################
